# %%
import tkinter
from tkinter import *
import json
import random
import re

# Function to send message and get response
def send():
    msg = EntryBox.get("1.0",'end-1c').strip()
    EntryBox.delete("0.0",END)    
    if msg != "":
        ChatLog.config(state=NORMAL)
        ChatLog.insert(END, "You: " + msg + '\n\n')
        ChatLog.config(foreground="#442265", font=("Verdana", 12))
        
        # Load patterns from JSON file
        with open('./data/pairs_final.json', 'r') as file:
            patterns = json.load(file)
        
        # Default response if no pattern matches
        default_response = "Sorry! I don't understand"
        
        matched_response = default_response
        
        # Match user input against patterns
        msg_lower = msg.lower()
        for pattern in patterns:
            if re.match(pattern['pattern'], msg_lower):
                matched_response = random.choice(pattern['responses'])
                break
        
        ChatLog.insert(END, "Bot: " + matched_response + '\n\n')
        ChatLog.config(state=DISABLED)
        ChatLog.yview(END)

# GUI setup
base = Tk()
base.title("Chatbot")
base.geometry("450x600")
base.resizable(width=FALSE, height=FALSE)

# Inserting starting comment in ChatLog
ChatLog = Text(base, bd=0, bg="white", height="16", width="400", font="Arial")
ChatLog.config(state=NORMAL)  # Set state to NORMAL to allow inserting text
ChatLog.insert(END, "Bot: Hi! I am a chatbot created by Anna Hojdila for your service. Enter which MIS course you would like information on, or 'quit' if you are finished.\n\n")
ChatLog.config(state=DISABLED) # Set state back to DISABLED after inserting text

scrollbar = Scrollbar(base, command=ChatLog.yview, cursor="heart")
ChatLog['yscrollcommand'] = scrollbar.set

SendButton = Button(base, font=("Verdana",12,'bold'), text="Send", width="12", height=5, bd=0, bg="#32de97", activebackground="#3c9d9b",fg='#ffffff', command=send)

EntryBox = Text(base, bd=0, bg="white",width="60", height="5", font="Arial")

scrollbar.place(x=420,y=8, height=500)
ChatLog.place(x=6,y=6, height=500, width=415)
EntryBox.place(x=128, y=505, height=25, width=293)
SendButton.place(x=6, y=505, height=25)

base.mainloop()

# %%
import tkinter
from tkinter import *
import json
import random
import re

# Function to send message and get response
def send():
    msg = EntryBox.get().strip()  # Use get() directly for single-line input
    EntryBox.delete(0, END)  # Clear the EntryBox
    
    if msg != "":
        ChatLog.config(state=NORMAL)
        ChatLog.insert(END, "You: " + msg + '\n\n')
        ChatLog.config(foreground="#442265", font=("Verdana", 12))
        
        # Load patterns from JSON file
        with open('./data/pairs_final.json', 'r') as file:
            patterns = json.load(file)
        
        # Default response if no pattern matches
        default_response = "Sorry! I don't understand"
        
        matched_response = default_response
        
        # Match user input against patterns
        msg_lower = msg.lower()
        for pattern in patterns:
            if re.match(pattern['pattern'], msg_lower):
                matched_response = random.choice(pattern['responses'])
                break
        
        ChatLog.insert(END, "Bot: " + matched_response + '\n\n')
        ChatLog.config(state=DISABLED)
        ChatLog.yview(END)

# GUI setup
base = Tk()
base.title("Chatbot")
base.geometry("450x600")
base.resizable(width=FALSE, height=FALSE)

# Inserting starting comment in ChatLog
ChatLog = Text(base, bd=0, bg="white", height="16", width="400", font="Arial")
ChatLog.config(state=NORMAL)  # Set state to NORMAL to allow inserting text
ChatLog.insert(END, "Bot: Hi! I am a chatbot created by Anna Hojdila for your service. Enter which MIS course you would like information on, or 'quit' if you are finished.\n\n")
ChatLog.config(state=DISABLED)  # Set state back to DISABLED after inserting text

scrollbar = Scrollbar(base, command=ChatLog.yview, cursor="heart")
ChatLog['yscrollcommand'] = scrollbar.set

SendButton = Button(base, font=("Verdana",12,'bold'), text="Send", width="12", height=5, bd=0, bg="#32de97", activebackground="#3c9d9b",fg='#ffffff', command=send)

EntryBox = Entry(base, bd=0, bg="white", width="60", font="Arial")  # Use Entry for single-line input

scrollbar.place(x=420, y=8, height=500)
ChatLog.place(x=6, y=6, height=500, width=415)
EntryBox.place(x=128, y=505, height=25, width=293)
SendButton.place(x=6, y=505, height=25)

base.mainloop()

# %%
import tkinter
from tkinter import *
import json
import random
import re

# Function to send message and get response
def send():
    msg = EntryBox.get().strip()  # Retrieve text from EntryBox
    EntryBox.delete(0, 'end')  # Clear text from EntryBox
    
    if msg != "":
        ChatLog.config(state=NORMAL)
        ChatLog.insert(END, "You: " + msg + '\n\n')
        ChatLog.config(foreground="#442265", font=("Verdana", 12))
        
        # Load patterns from JSON file
        with open('./data/pairs_final.json', 'r') as file:
            patterns = json.load(file)
        
        # Default response if no pattern matches
        default_response = "Sorry! I don't understand"
        
        matched_response = default_response
        
        # Match user input against patterns
        msg_lower = msg.lower()
        for pattern in patterns:
            if re.match(pattern['pattern'], msg_lower):
                matched_response = random.choice(pattern['responses'])
                break
        
        ChatLog.insert(END, "Bot: " + matched_response + '\n\n')
        ChatLog.config(state=DISABLED)
        ChatLog.yview(END)

# GUI setup
base = Tk()
base.title("Chatbot")
base.geometry("450x600")
base.resizable(width=FALSE, height=FALSE)

# Inserting starting comment in ChatLog
ChatLog = Text(base, bd=0, bg="white", height="16", width="400", font="Arial")
ChatLog.config(state=NORMAL)  # Set state to NORMAL to allow inserting text
ChatLog.insert(END, "Bot: Hi! I am a chatbot created by Anna Hojdila for your service. Enter which MIS course you would like information on, or 'quit' if you are finished.\n\n")
ChatLog.config(state=DISABLED)  # Set state back to DISABLED after inserting text

scrollbar = Scrollbar(base, command=ChatLog.yview, cursor="heart")
ChatLog['yscrollcommand'] = scrollbar.set

SendButton = Button(base, font=("Verdana",12,'bold'), text="Send", width="12", height=5, bd=0, bg="#32de97", activebackground="#3c9d9b",fg='#ffffff', command=send)

EntryBox = Entry(base, bd=0, bg="white", width="60", font="Arial")  # Use Entry for single-line input

scrollbar.place(x=420, y=8, height=500)
ChatLog.place(x=6, y=6, height=500, width=415)
EntryBox.place(x=128, y=505, height=25, width=293)
SendButton.place(x=6, y=505, height=25)

base.mainloop()

# %%
import tkinter
from tkinter import *
import json
import random
import re

# Function to send message and get response
def send():
    msg = EntryBox.get().strip()  # Retrieve text from EntryBox
    EntryBox.delete(0, 'end')  # Clear text from EntryBox
    
    if msg != "":
        ChatLog.config(state=NORMAL)
        ChatLog.insert(END, "You: " + msg + '\n\n')
        ChatLog.config(foreground="#442265", font=("Verdana", 12))
        
        # Load patterns from JSON file
        with open('./data/pairs_final.json', 'r') as file:
            patterns = json.load(file)
        
        # Default response if no pattern matches
        default_response = "Sorry! I don't understand"
        
        matched_response = default_response
        
        # Match user input against patterns
        msg_lower = msg.lower()
        for pattern in patterns:
            if re.match(pattern['pattern'], msg_lower):
                matched_response = random.choice(pattern['responses'])
                break
        
        ChatLog.insert(END, "Bot: " + matched_response + '\n\n')
        ChatLog.config(state=DISABLED)
        ChatLog.yview(END)

# GUI setup
base = Tk()
base.title("Chatbot")
base.geometry("450x600")
base.resizable(width=FALSE, height=FALSE)

# Inserting starting comment in ChatLog
ChatLog = Text(base, bd=0, bg="white", height="16", width="400", font="Arial")
ChatLog.config(state=NORMAL)  # Set state to NORMAL to allow inserting text
ChatLog.insert(END, "Bot: Hi! I am a chatbot created by Anna Hojdila for your service. Enter which MIS course you would like information on, or 'quit' if you are finished.\n\n")
ChatLog.config(state=DISABLED)  # Set state back to DISABLED after inserting text

scrollbar = Scrollbar(base, command=ChatLog.yview, cursor="heart")
ChatLog['yscrollcommand'] = scrollbar.set

SendButton = Button(base, font=("Verdana",12,'bold'), text="Send", width="12", height=5, bd=0, bg="#32de97", activebackground="#3c9d9b",fg='#ffffff', command=send)

EntryBox = Entry(base, bd=0, bg="white", width="60", font="Arial")  # Use Entry for single-line input

scrollbar.place(x=420, y=8, height=500)
ChatLog.place(x=6, y=6, height=500, width=415)
EntryBox.place(x=128, y=505, height=25, width=293)
SendButton.place(x=6, y=505, height=25)

base.mainloop()

# %%
import tkinter
from tkinter import *
import json
import re

# Function to send message and get response
def send():
    msg = EntryBox.get().strip()  # Retrieve text from EntryBox
    EntryBox.delete(0, 'end')  # Clear text from EntryBox
    
    if msg != "":
        ChatLog.config(state=NORMAL)
        ChatLog.insert(END, "You: " + msg + '\n\n')
        ChatLog.config(foreground="#442265", font=("Verdana", 12))
        
        # Load patterns from JSON file
        with open('./data/pairs_final.json', 'r') as file:
            patterns = json.load(file)
        
        # Default response if no pattern matches
        default_response = "Sorry! I don't understand"
        
        matched_response = default_response
        
        # Match user input against patterns
        msg_lower = msg.lower()
        for pattern in patterns:
            if re.match(pattern['pattern'], msg_lower):
                matched_response = pattern['responses'][0]  # Select the first response
                break
        
        ChatLog.insert(END, "Bot: " + matched_response + '\n\n')
        ChatLog.config(state=DISABLED)
        ChatLog.yview(END)

# GUI setup
base = Tk()
base.title("Chatbot")
base.geometry("450x600")
base.resizable(width=FALSE, height=FALSE)

# Inserting starting comment in ChatLog
ChatLog = Text(base, bd=0, bg="white", height="16", width="400", font="Arial")
ChatLog.config(state=NORMAL)  # Set state to NORMAL to allow inserting text
ChatLog.insert(END, "Bot: Hi! I am a chatbot created by Anna Hojdila for your service. Enter which MIS course you would like information on, or 'quit' if you are finished.\n\n")
ChatLog.config(state=DISABLED)  # Set state back to DISABLED after inserting text

scrollbar = Scrollbar(base, command=ChatLog.yview, cursor="heart")
ChatLog['yscrollcommand'] = scrollbar.set

SendButton = Button(base, font=("Verdana",12,'bold'), text="Send", width="12", height=5, bd=0, bg="#32de97", activebackground="#3c9d9b",fg='#ffffff', command=send)

EntryBox = Entry(base, bd=0, bg="white", width="60", font="Arial")  # Use Entry for single-line input

scrollbar.place(x=420, y=8, height=500)
ChatLog.place(x=6, y=6, height=500, width=415)
EntryBox.place(x=128, y=505, height=25, width=293)
SendButton.place(x=6, y=505, height=25)

base.mainloop()
